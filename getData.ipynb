# %%
import os, subprocess

# %%
t = !ls bash/*

# %%
# !mkdir data
for i in t:
    l = i.split('/')[1][:-3]
    try:
        os.mkdir('./data/' + l)
    except OSError as e:
        pass
    os.chdir('./data/' + l)
    subprocess.call(['sh', '../../{}'.format(i)])
    os.chdir('/Users/yoshitakainoue/code/scRNAData/')
# Out:
# --2022-05-31 15:37:17--  https://www.ncbi.nlm.nih.gov/geo/download/?acc=GSE84133&format=file
# Resolving www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)... 2607:f220:41e:4290::110, 130.14.29.110
# Connecting to www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)|2607:f220:41e:4290::110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29122560 (28M) [application/x-tar]
# Saving to: ‘data.tar’
#
#      0K .......... .......... .......... .......... ..........  0%  838K 34s
#     50K .......... .......... .......... .......... ..........  0% 1.77M 25s
#    100K .......... .......... .......... .......... ..........  0% 22.4M 17s
#    150K .......... .......... .......... .......... ..........  0% 1.83M 16s
#    200K .......... .......... .......... .......... ..........  0% 19.5M 13s
#    250K .......... .......... .......... .......... ..........  1% 87.7M 11s
#    300K .......... .......... .......... .......... ..........  1% 54.2M 10s
# ...

# %%
import pandas as pd

# %%
pd.read_csv('../baron/GSM2230762_mouse2_umifm_counts.csv')
# Out:
#                        Unnamed: 0               barcode    assigned_cluster  \
# 0     mouse2_lib1.final_cell_0001   GAAAGATTGT-AAACCTCC                beta
# 1     mouse2_lib1.final_cell_0002    ACTCCGCAT-GTTAACCA                beta
# 2     mouse2_lib1.final_cell_0003    AGGGAACGA-GCTTTCCA                beta
# 3     mouse2_lib1.final_cell_0004    AAATGACCC-ACTCACCG              ductal
# 4     mouse2_lib1.final_cell_0005    AAGTGAAAG-GAAGTGCC                beta
# ...                           ...                   ...                 ...
# 1059  mouse2_lib3.final_cell_0391  TGATTGCACGC-CATTTGTT                beta
# 1060  mouse2_lib3.final_cell_0392     TAACTACT-AAGTAATC                beta
# 1061  mouse2_lib3.final_cell_0393  TGACCTGTTAT-TGATGCCC              ductal
# 1062  mouse2_lib3.final_cell_0394  TGAGTAATCCC-AACCCTTG  quiescent_stellate
# 1063  mouse2_lib3.final_cell_0395    AGCACCTCT-ATTCCTTG              ductal
#
# ...
